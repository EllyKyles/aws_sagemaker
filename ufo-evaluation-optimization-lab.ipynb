# %% [markdown]
# ## UFO Sightings Evaluation and Optimization Lab
#
# The goal of this notebook is to find out if the optimized model hyperparmeters out performs the training of our baseline Linear Learner model. Compare things like accurary and see if they differ.
#
# 1. [Create and train our "optimized" model (Linear Learner)](#1.-Create-and-train-our-%22optimized%22-model-(Linear-Learner))
# 1. Compare the results!

# %% [markdown]
# import all the needed libraries.

# %%
import pandas as pd
import numpy as np
from datetime import datetime


import boto3
from sagemaker import get_execution_role
import sagemaker

# %%
role = get_execution_role()
bucket='ml-lab-ufo-elly'

# %% [markdown]
# ---
#
# ### 1. Create and train our "optimized" model (Linear Learner)
# evaluate the Linear Learner algorithm with the new optimized hyperparameters.  go ahead and get the data that we already stored into S3 as recordIO protobuf data.

# %% [markdown]
# get the recordIO file for the training data that is in S3

# %%
train_file = 'ufo_sightings_train_recordIO_protobuf.data'
training_recordIO_protobuf_location = 's3://{}/algorithms_lab/linearlearner_train/{}'.format(bucket, train_file)
print('The Pipe mode recordIO protobuf training data: {}'.format(training_recordIO_protobuf_location))
# Out:
# The Pipe mode recordIO protobuf training data: s3://ml-lab-ufo-elly/algorithms_lab/linearlearner_train/ufo_sightings_train_recordIO_protobuf.data

# %% [markdown]
# get the recordIO file for the validation data that is in S3

# %%
validation_file = 'ufo_sightings_validatioin_recordIO_protobuf.data'
validate_recordIO_protobuf_location = 's3://{}/algorithms_lab/linearlearner_validation/{}'.format(bucket, validation_file)
print('The Pipe mode recordIO protobuf validation data: {}'.format(validate_recordIO_protobuf_location))
# Out:
# The Pipe mode recordIO protobuf validation data: s3://ml-lab-ufo-elly/algorithms_lab/linearlearner_validation/ufo_sightings_validatioin_recordIO_protobuf.data

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
import sagemaker

container = get_image_uri(boto3.Session().region_name, 'linear-learner', "1")
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.

# %% [markdown]
# Create a job and use the optimzed hyperparamters.

# %%
# Create a training job name
job_name = 'ufo-linear-learner-job-optimized-{}'.format(datetime.now().strftime("%Y%m%d%H%M%S"))
print('Here is the job name {}'.format(job_name))

# Here is where the model-artifact will be stored
output_location = 's3://{}/optimization_evaluation_lab/linearlearner_optimized_output'.format(bucket)
# Out:
# Here is the job name ufo-linear-learner-job-optimized-20200810030637

# %% [markdown]
# Next start building out my model by using the SageMaker Python SDK and passing in everything that is required to create a Linear Learner training job.
#
# Here are the [linear learner hyperparameters](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html)

# %%
# %%time
sess = sagemaker.Session()

# Setup the LinearLeaner algorithm from the ECR container
linear = sagemaker.estimator.Estimator(container,
                                       role, 
                                       train_instance_count=1, 
                                       train_instance_type='ml.c4.xlarge',
                                       output_path=output_location,
                                       sagemaker_session=sess,
                                       input_mode='Pipe')
# Setup the hyperparameters
linear.set_hyperparameters( feature_dim=22, 
                            predictor_type='multiclass_classifier',
                            num_classes=3,
                            l1 = 0.00015634445960768285,
                            learning_rate= 0.02986332628768753,
                            mini_batch_size = 1978,
                            use_bias='true',
                            wd=0.0028658419345028887
                          )


# Launch a training job. This method calls the CreateTrainingJob API call
data_channels = {
    'train': training_recordIO_protobuf_location,
    'validation': validate_recordIO_protobuf_location
}
linear.fit(data_channels, job_name=job_name)
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 2020-08-10 03:07:04 Starting - Starting the training job...
# 2020-08-10 03:07:06 Starting - Launching requested ML instances......
# 2020-08-10 03:08:17 Starting - Preparing the instances for training...
# 2020-08-10 03:09:05 Downloading - Downloading input data...
# 2020-08-10 03:09:21 Training - Downloading the training image.........
# 2020-08-10 03:10:59 Uploading - Uploading generated training modelDocker entrypoint called with argument(s): train
# Running default environment configuration script
# [08/10/2020 03:10:51 INFO 139925855733568] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [08/10/2020 03:10:51 INFO 139925855733568] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'wd': u'0.0028658419345028887', u'predictor_type': u'multiclass_classifier', u'learning_rate': u'0.02986332628768753', u'feature_dim': u'22', u'l1': u'0.00015634445960768285', u'mini_batch_size': u'1978', u'use_bias': u'true', u'num_classes': u'3'}
# [08/10/2020 03:10:52 INFO 139925855733568] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'22', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'0.0028658419345028887', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'0.02986332628768753', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1978', u'huber_delta': u'1.0', u'num_classes': u'3', u'predictor_type': u'multiclass_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'0.00015634445960768285', u'margin': u'1.0'}
# [08/10/2020 03:10:52 WARNING 139925855733568] Loggers have already been setup.
# Process 1 is a worker.
# [08/10/2020 03:10:52 INFO 139925855733568] Using default worker.
# [08/10/2020 03:10:52 INFO 139925855733568] Checkpoint loading and saving are disabled.
# [08/10/2020 03:10:52 INFO 139925855733568] The channel 'train' is in pipe input mode under /opt/ml/input/data/train.
# [08/10/2020 03:10:52 INFO 139925855733568] The channel 'validation' is in pipe input mode under /opt/ml/input/data/validation.
# [2020-08-10 03:10:52.214] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2020-08-10 03:10:52.274] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 68, "num_examples": 1, "num_bytes": 261096}
# [08/10/2020 03:10:52 INFO 139925855733568] Create Store: local
# [2020-08-10 03:10:52.460] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 184, "num_examples": 6, "num_bytes": 1566576}
# [08/10/2020 03:10:52 INFO 139925855733568] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f42b050b4d0>
# [08/10/2020 03:10:52 INFO 139925855733568] Scaling model computed with parameters:
#  {'stdev_weight':
# [28.550726    2.8857977  10.054421   38.392174    0.35589468  0.26621193
#   0.3812663   0.32136446  0.37779763  0.35472676  0.3532136   0.3255361
#   0.3247486   0.10368904  0.47229064  0.47152355  0.28725076  0.10758714
#   0.10004492  0.23047282  0.28868595  0.23559128]
# <NDArray 22 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [ 5.04427032e+01  5.50539255e+00  3.77528915e+01 -8.72145386e+01
#   1.48803502e-01  7.67610371e-02  1.76525116e-01  1.16953149e-01
#   1.72480613e-01  1.47623867e-01  1.46107182e-01  1.20492078e-01
#   1.19817995e-01  1.08695654e-02  3.35861146e-01  3.33670348e-01
#   9.07482281e-02  1.17121674e-02  1.01112239e-02  5.62858097e-02
#   9.17593539e-02  5.89821376e-02]
# <NDArray 22 @cpu(0)>}
# [08/10/2020 03:10:52 INFO 139925855733568] nvidia-smi took: 0.0251789093018 secs to identify 0 gpus
# [08/10/2020 03:10:52 INFO 139925855733568] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 6, "sum": 6.0, "min": 6}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 7, "sum": 7.0, "min": 7}, "Total Records Seen": {"count": 1, "max": 13846, "sum": 13846.0, "min": 13846}, "Max Records Seen Between Resets": {"count": 1, "max": 11868, "sum": 11868.0, "min": 11868}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1597029052.672079, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1597029052.67205}
#
# [2020-08-10 03:10:53.034] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 361, "num_examples": 8, "num_bytes": 1904760}
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6740016427564256, "sum": 0.6740016427564256, "min": 0.6740016427564256}}, "EndTime": 1597029053.034272, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597029053.034184}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6251434189519424, "sum": 0.6251434189519424, "min": 0.6251434189519424}}, "EndTime": 1597029053.034361, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597029053.034341}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.5255464176110203, "sum": 0.5255464176110203, "min": 0.5255464176110203}}, "EndTime": 1597029053.034425, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597029053.034408}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.
"Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597029053.095575}
#
# [08/10/2020 03:10:53 INFO 139925855733568] #quality_metric: host=algo-1, epoch=0, validation multiclass_cross_entropy_objective <loss>=0.441095359703
# [08/10/2020 03:10:53 INFO 139925855733568] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=multiclass_cross_entropy_objective, value=0.219050907107
# [08/10/2020 03:10:53 INFO 139925855733568] Epoch 0: Loss improved. Updating best model
# [08/10/2020 03:10:53 INFO 139925855733568] Saving model for epoch: 0
# [08/10/2020 03:10:53 INFO 139925855733568] Saved checkpoint to "/tmp/tmpmBPnpC/mx-mod-0000.params"
# [08/10/2020 03:10:53 INFO 139925855733568] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 8, "sum": 8.0, "min": 8}, "Number of Batches Since Last Reset": {"count": 1, "max": 8, "sum": 8.0, "min": 8}, "Number of Records Since Last Reset": {"count": 1, "max": 14430, "sum": 14430.0, "min": 14430}, "Total Batches Seen": {"count": 1, "max": 15, "sum": 15.0, "min": 15}, "Total Records Seen": {"count": 1, "max": 28276, "sum": 28276.0, "min": 28276}, "Max Records Seen Between Resets": {"count": 1, "max": 14430, "sum": 14430.0, "min": 14430}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1597029053.103861, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1597029052.672308}
#
# [08/10/2020 03:10:53 INFO 139925855733568] #throughput_metric: host=algo-1, train throughput=33429.7757717 records/second
# [2020-08-10 03:10:53.482] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 377, "num_examples": 8, "num_bytes": 1904760}
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.3238250476749546, "sum": 0.3238250476749546, "min": 0.3238250476749546}}, "EndTime": 1597029053.482352, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1597029053.482263}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.3285506547539113, "sum": 0.3285506547539113, "min": 0.3285506547539113}}, "EndTime": 1597029053.482557, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1597029053.482533}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.25057320634047625, "sum": 0.25057320634047625, "min": 0.25057320634047625}}, "EndTime": 1597029053.482733, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1597029053.48261}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.25500668794730313, "sum": 0.25500668794730313, "min": 0.25500668794730313}}, "EndTime": 1597029053.482891, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1597029053.482868}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.22922898606208472, "sum": 0.22922898606208472, "min": 0.22922898606208472}}, "EndTime": 1597029053.483009, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1597029053.482941}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.29784323331267265, "sum": 0.29784323331267265, "min": 0.29784323331267265}}, "EndTime": 1597029053.483126, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1597029053.483101}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.27512426953534075, "sum": 0.27512426953534075, "min": 0.27512426953534075}}, "EndTime": 1597029053.483289, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1597029053.483266}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2957040515917842, "sum": 0.2957040515917842, "min": 0.2957040515917842}}, "EndTime": 1597029053.483358, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1597029053.483339}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.22132763111159134, "sum": 0.22132763111159134, "min": 0.22132763111159134}}, "EndTime": 1597029053.483564, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1597029053.483403}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.26767989140309023, "sum": 0.26767989140309023, "min": 0.26767989140309023}}, "EndTime": 1597029053.483739, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1597029053.483716}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.5043608442166284, "sum": 0.5043608442166284, "min": 0.5043608442166284}}, "EndTime": 1597029053.483926, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1597029053.483794}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2678080074845341, "sum": 0.2678080074845341, "min": 0.2678080074845341}}, "EndTime": 1597029053.48397, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1597029053.48396}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.4604228316024258, "sum": 0.4604228316024258, "min": 0.4604228316024258}}, "EndTime": 1597029053.484026, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1597029053.484009}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.40667425737239093, "sum": 0.40667425737239093, "min": 0.40667425737239093}}, "EndTime": 1597029053.484175, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1597029053.484159}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.3127456966996899, "sum": 0.3127456966996899, "min": 0.3127456966996899}}, "EndTime": 1597029053.484259, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1597029053.484241}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6262089245653076, "sum": 0.6262089245653076, "min": 0.6262089245653076}}, "EndTime": 1597029053.484321, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1597029053.484304}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6063002493104959, "sum": 0.6063002493104959, "min": 0.6063002493104959}}, "EndTime": 1597029053.484382, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1597029053.484365}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.
"Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 12}, "StartTime": 1597029058.384428}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.20111250944616293, "sum": 0.20111250944616293, "min": 0.20111250944616293}}, "EndTime": 1597029058.384495, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 12}, "StartTime": 1597029058.38448}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.1885329330969314, "sum": 0.1885329330969314, "min": 0.1885329330969314}}, "EndTime": 1597029058.384576, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 12}, "StartTime": 1597029058.384558}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2459063586446436, "sum": 0.2459063586446436, "min": 0.2459063586446436}}, "EndTime": 1597029058.384641, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 12}, "StartTime": 1597029058.384624}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.21586940225341936, "sum": 0.21586940225341936, "min": 0.21586940225341936}}, "EndTime": 1597029058.384709, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 12}, "StartTime": 1597029058.384691}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.4741610609335343, "sum": 0.4741610609335343, "min": 0.4741610609335343}}, "EndTime": 1597029058.384771, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 12}, "StartTime": 1597029058.384753}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.22348788412559928, "sum": 0.22348788412559928, "min": 0.22348788412559928}}, "EndTime": 1597029058.384828, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 12}, "StartTime": 1597029058.384812}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.217301335902249, "sum": 0.217301335902249, "min": 0.217301335902249}}, "EndTime": 1597029058.384886, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 12}, "StartTime": 1597029058.38487}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.19087930970856246, "sum": 0.19087930970856246, "min": 0.19087930970856246}}, "EndTime": 1597029058.384944, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 12}, "StartTime": 1597029058.384928}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.3624452783506063, "sum": 0.3624452783506063, "min": 0.3624452783506063}}, "EndTime": 1597029058.38501, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 12}, "StartTime": 1597029058.384993}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.18887299840489283, "sum": 0.18887299840489283, "min": 0.18887299840489283}}, "EndTime": 1597029058.385068, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 12}, "StartTime": 1597029058.385053}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.19541155733903517, "sum": 0.19541155733903517, "min": 0.19541155733903517}}, "EndTime": 1597029058.385122, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 12}, "StartTime": 1597029058.385109}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.18795297862578433, "sum": 0.18795297862578433, "min": 0.18795297862578433}}, "EndTime": 1597029058.385175, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 12}, "StartTime": 1597029058.38516}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.20620453861965948, "sum": 0.20620453861965948, "min": 0.20620453861965948}}, "EndTime": 1597029058.385232, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 12}, "StartTime": 1597029058.385217}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.18813042121624718, "sum": 0.18813042121624718, "min": 0.18813042121624718}}, "EndTime": 1597029058.38529, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 12}, "StartTime": 1597029058.385274}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.3319236381001481, "sum": 0.3319236381001481, "min": 0.3319236381001481}}, "EndTime": 1597029058.385356, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 12}, "StartTime": 1597029058.385339}
#
# [08/10/2020 03:10:58 INFO 139925855733568] #quality_metric: host=algo-1, epoch=12, validation multiclass_cross_entropy_objective <loss>=0.189085364947
# [08/10/2020 03:10:58 INFO 139925855733568] #early_stopping_criteria_metric: host=algo-1, epoch=12, criteria=multiclass_cross_entropy_objective, value=0.187952978626
# [08/10/2020 03:10:58 INFO 139925855733568] Saving model for epoch: 12
# [08/10/2020 03:10:58 INFO 139925855733568] Saved checkpoint to "/tmp/tmpphnkaB/mx-mod-0000.params"
# [08/10/2020 03:10:58 INFO 139925855733568] Early stop condition met. Stopping training.
# [08/10/2020 03:10:58 INFO 139925855733568] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 8, "sum": 8.0, "min": 8}, "Number of Batches Since Last Reset": {"count": 1, "max": 8, "sum": 8.0, "min": 8}, "Number of Records Since Last Reset": {"count": 1, "max": 14430, "sum": 14430.0, "min": 14430}, "Total Batches Seen": {"count": 1, "max": 111, "sum": 111.0, "min": 111}, "Total Records Seen": {"count": 1, "max": 201436, "sum": 201436.0, "min": 201436}, "Max Records Seen Between Resets": {"count": 1, "max": 14430, "sum": 14430.0, "min": 14430}, "Reset Count": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1597029058.391912, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 12}, "StartTime": 1597029057.990122}
#
# [08/10/2020 03:10:58 INFO 139925855733568] #throughput_metric: host=algo-1, train throughput=35903.3841616 records/second
# [08/10/2020 03:10:58 WARNING 139925855733568] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [08/10/2020 03:10:58 WARNING 139925855733568] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2020-08-10 03:10:58.443] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 41, "duration": 37, "num_examples": 1, "num_bytes": 234036}
# [08/10/2020 03:10:58 INFO 139925855733568] #early_stopping_criteria_metric: host=algo-1, epoch=12, criteria=multiclass_cross_entropy_objective, value=0.187952978626
# [2020-08-10 03:10:58.473] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 43, "duration": 20, "num_examples": 1, "num_bytes": 234036}
# [08/10/2020 03:10:58 INFO 139925855733568] #validation_score (algo-1) : ('multiclass_cross_entropy_objective', 0.1875097077913494)
# [08/10/2020 03:10:58 INFO 139925855733568] #validation_score (algo-1) : ('multiclass_accuracy', 0.9419063733784546)
# [08/10/2020 03:10:58 INFO 139925855733568] #validation_score (algo-1) : ('multiclass_top_k_accuracy_3', 1.0)
# [08/10/2020 03:10:58 INFO 139925855733568] #validation_score (algo-1) : ('dcg', 0.9770085764549845)
# [08/10/2020 03:10:58 INFO 139925855733568] #validation_score (algo-1) : ('macro_recall', 0.9327631)
# [08/10/2020 03:10:58 INFO 139925855733568] #validation_score (algo-1) : ('macro_precision', 0.89566827)
# [08/10/2020 03:10:58 INFO 139925855733568] #validation_score (algo-1) : ('macro_f_1.000', 0.9128248)
# [08/10/2020 03:10:58 INFO 139925855733568] #quality_metric: host=algo-1, validation multiclass_cross_entropy_objective <loss>=0.187509707791
# [08/10/2020 03:10:58 INFO 139925855733568] #quality_metric: host=algo-1, validation multiclass_accuracy <score>=0.941906373378
# [08/10/2020 03:10:58 INFO 139925855733568] #quality_metric: host=algo-1, validation multiclass_top_k_accuracy_3 <score>=1.0
# [08/10/2020 03:10:58 INFO 139925855733568] #quality_metric: host=algo-1, validation dcg <score>=0.977008576455
# [08/10/2020 03:10:58 INFO 139925855733568] #quality_metric: host=algo-1, validation macro_recall <score>=0.93276309967
# [08/10/2020 03:10:58 INFO 139925855733568] #quality_metric: host=algo-1, validation macro_precision <score>=0.895668268204
# [08/10/2020 03:10:58 INFO 139925855733568] #quality_metric: host=algo-1, validation macro_f_1.000 <score>=0.912824809551
# [08/10/2020 03:10:58 INFO 139925855733568] Best model found for hyperparameters: {"lr_scheduler_step": 216, "wd": 0.0004653088747992106, "optimizer": "adam", "lr_scheduler_factor": 0.9316602901273723, "l1": 0.00031502989657088544, "learning_rate": 0.1004722437624804, "lr_scheduler_minimum_lr": 1.998391905573772e-06}
# [08/10/2020 03:10:58 INFO 139925855733568] Saved checkpoint to "/tmp/tmpyAK2n4/mx-mod-0000.params"
# [08/10/2020 03:10:58 INFO 139925855733568] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 6508.620977401733, "sum": 6508.620977401733, "min": 6508.620977401733}, "finalize.time": {"count": 1, "max": 100.49891471862793, "sum": 100.49891471862793, "min": 100.49891471862793}, "initialize.time": {"count": 1, "max": 421.4658737182617, "sum": 421.4658737182617, "min": 421.4658737182617}, "check_early_stopping.time": {"count": 14, "max": 1.1110305786132812, "sum": 8.634328842163086, "min": 0.18715858459472656}, "setuptime": {"count": 1, "max": 23.823976516723633, "sum": 23.823976516723633, "min": 23.823976516723633}, "update.time": {"count": 13, "max": 530.8749675750732, "sum": 5660.305738449097, "min": 388.49902153015137}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1597029058.502557, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1597029052.202976}
#
#
# 2020-08-10 03:11:06 Completed - Training job completed
# Training seconds: 121
# Billable seconds: 121
# CPU times: user 771 ms, sys: 28.4 ms, total: 799 ms
# Wall time: 4min 42s

# %% [markdown]
# compare the amount of time billed and the accuracy compared to our baseline model.
