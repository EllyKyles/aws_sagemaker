# %% [markdown]
# ## UFO Sightings Evaluation and Optimization Lab
#
# The goal of this notebook is to find out if our optimized model hyperparmeters out performs the training of our baseline Linear Learner model. We can also compare things like accurary and see if they differ.
#
# What we plan on accompishling is the following:
# 1. [Create and train our "optimized" model (Linear Learner)](#1.-Create-and-train-our-%22optimized%22-model-(Linear-Learner))
# 1. Compare the results!

# %% [markdown]
# First let's go ahead and import all the needed libraries.

# %%
import pandas as pd
import numpy as np
from datetime import datetime


import boto3
from sagemaker import get_execution_role
import sagemaker

# %%
role = get_execution_role()
bucket='ml-lab-ufo-elly'

# %% [markdown]
# ---
#
# ### 1. Create and train our "optimized" model (Linear Learner)
#
# Let's evaluate the Linear Learner algorithm with the new optimized hyperparameters. Let's go ahead and get the data that we already stored into S3 as recordIO protobuf data.

# %% [markdown]
# Let's get the recordIO file for the training data that is in S3

# %%
train_file = 'ufo_sightings_train_recordIO_protobuf.data'
training_recordIO_protobuf_location = 's3://{}/algorithms_lab/linearlearner_train/{}'.format(bucket, train_file)
print('The Pipe mode recordIO protobuf training data: {}'.format(training_recordIO_protobuf_location))
# Out:
# The Pipe mode recordIO protobuf training data: s3://ml-lab-ufo-elly/algorithms_lab/linearlearner_train/ufo_sightings_train_recordIO_protobuf.data

# %% [markdown]
# Let's get the recordIO file for the validation data that is in S3

# %%
validation_file = 'ufo_sightings_validatioin_recordIO_protobuf.data'
validate_recordIO_protobuf_location = 's3://{}/algorithms_lab/linearlearner_validation/{}'.format(bucket, validation_file)
print('The Pipe mode recordIO protobuf validation data: {}'.format(validate_recordIO_protobuf_location))
# Out:
# The Pipe mode recordIO protobuf validation data: s3://ml-lab-ufo-elly/algorithms_lab/linearlearner_validation/ufo_sightings_validatioin_recordIO_protobuf.data

# %% [markdown]
# ---
#
# Alright we are good to go for the Linear Learner algorithm. Let's get everything we need from the ECR repository to call the Linear Learner algorithm.

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
import sagemaker

container = get_image_uri(boto3.Session().region_name, 'linear-learner', "1")
# Out:
# WARNING:sagemaker.amazon.amazon_estimator:'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.

# %% [markdown]
# Let's create a job and use the optimzed hyperparamters.

# %%
# Create a training job name
job_name = 'ufo-linear-learner-job-optimized-{}'.format(datetime.now().strftime("%Y%m%d%H%M%S"))
print('Here is the job name {}'.format(job_name))

# Here is where the model-artifact will be stored
output_location = 's3://{}/optimization_evaluation_lab/linearlearner_optimized_output'.format(bucket)
# Out:
# Here is the job name ufo-linear-learner-job-optimized-20200713034540

# %% [markdown]
# Next we can start building out our model by using the SageMaker Python SDK and passing in everything that is required to create a Linear Learner training job.
#
# Here are the [linear learner hyperparameters](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html) that we can use within our training job.
#
# After we run this job we can view the results.

# %%
# %%time
sess = sagemaker.Session()

# Setup the LinearLeaner algorithm from the ECR container
linear = sagemaker.estimator.Estimator(container,
                                       role, 
                                       train_instance_count=1, 
                                       train_instance_type='ml.c4.xlarge',
                                       output_path=output_location,
                                       sagemaker_session=sess,
                                       input_mode='Pipe')
# Setup the hyperparameters
linear.set_hyperparameters( feature_dim=22, 
                            predictor_type='multiclass_classifier',
                            num_classes=3,
                            l1 = 0.00015634445960768285,
                            learning_rate= 0.02986332628768753,
                            mini_batch_size = 1978,
                            use_bias='true',
                            wd=0.0028658419345028887
                          )


# Launch a training job. This method calls the CreateTrainingJob API call
data_channels = {
    'train': training_recordIO_protobuf_location,
    'validation': validate_recordIO_protobuf_location
}
linear.fit(data_channels, job_name=job_name)
# Out:
# WARNING:root:Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# WARNING:sagemaker:'s3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# WARNING:sagemaker:'s3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 2020-07-13 03:45:42 Starting - Starting the training job...
# 2020-07-13 03:45:44 Starting - Launching requested ML instances.........
# 2020-07-13 03:47:24 Starting - Preparing the instances for training.........
# 2020-07-13 03:49:07 Downloading - Downloading input data
# 2020-07-13 03:49:07 Training - Downloading the training image...
# 2020-07-13 03:49:38 Uploading - Uploading generated training modelDocker entrypoint called with argument(s): train
# Running default environment configuration script
# [07/13/2020 03:49:30 INFO 140591090407232] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [07/13/2020 03:49:30 INFO 140591090407232] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'wd': u'0.0028658419345028887', u'predictor_type': u'multiclass_classifier', u'learning_rate': u'0.02986332628768753', u'feature_dim': u'22', u'l1': u'0.00015634445960768285', u'mini_batch_size': u'1978', u'use_bias': u'true', u'num_classes': u'3'}
# [07/13/2020 03:49:30 INFO 140591090407232] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'22', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'0.0028658419345028887', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'0.02986332628768753', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1978', u'huber_delta': u'1.0', u'num_classes': u'3', u'predictor_type': u'multiclass_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'0.00015634445960768285', u'margin': u'1.0'}
# [07/13/2020 03:49:30 WARNING 140591090407232] Loggers have already been setup.
# Process 1 is a worker.
# [07/13/2020 03:49:30 INFO 140591090407232] Using default worker.
# [07/13/2020 03:49:30 INFO 140591090407232] Checkpoint loading and saving are disabled.
# [07/13/2020 03:49:30 INFO 140591090407232] The channel 'train' is in pipe input mode under /opt/ml/input/data/train.
# [07/13/2020 03:49:30 INFO 140591090407232] The channel 'validation' is in pipe input mode under /opt/ml/input/data/validation.
# [2020-07-13 03:49:30.271] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2020-07-13 03:49:30.326] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 65, "num_examples": 1, "num_bytes": 261096}
# [07/13/2020 03:49:30 INFO 140591090407232] Create Store: local
# [2020-07-13 03:49:30.420] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 93, "num_examples": 6, "num_bytes": 1566576}
# [07/13/2020 03:49:30 INFO 140591090407232] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fdd98c02310>
# [07/13/2020 03:49:30 INFO 140591090407232] Scaling model computed with parameters:
#  {'stdev_weight':
# [28.602688    2.897642   10.156868   39.173847    0.3550612   0.26621193
#   0.3833966   0.32366037  0.37350497  0.35812542  0.3523674   0.32166553
#   0.3260266   0.10565691  0.47261173  0.47071487  0.29385862  0.10289087
#   0.10248935  0.23160484  0.28519905  0.23288997]
# <NDArray 22 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [ 5.05140724e+01  5.52494097e+00  3.77019844e+01 -8.68205032e+01
#   1.47960901e-01  7.67610371e-02  1.79052919e-01  1.18891135e-01
#   1.67593524e-01  1.51078537e-01  1.45264581e-01  1.17205933e-01
#   1.20913379e-01  1.12908660e-02  3.36787999e-01  3.31395328e-01
#   9.54668000e-02  1.07010445e-02  1.06167849e-02  5.68756312e-02
#   8.93158093e-02  5.75497150e-02]
# <NDArray 22 @cpu(0)>}
# [07/13/2020 03:49:30 INFO 140591090407232] nvidia-smi took: 0.0252280235291 secs to identify 0 gpus
# [07/13/2020 03:49:30 INFO 140591090407232] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 6, "sum": 6.0, "min": 6}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 7, "sum": 7.0, "min": 7}, "Total Records Seen": {"count": 1, "max": 13846, "sum": 13846.0, "min": 13846}, "Max Records Seen Between Resets": {"count": 1, "max": 11868, "sum": 11868.0, "min": 11868}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1594612170.584794, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1594612170.584758}
#
# [2020-07-13 03:49:30.969] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 384, "num_examples": 8, "num_bytes": 1904760}
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6746322232898941, "sum": 0.6746322232898941, "min": 0.6746322232898941}}, "EndTime": 1594612170.969903, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1594612170
"Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1594612171.033479}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2691520781283048, "sum": 0.2691520781283048, "min": 0.2691520781283048}}, "EndTime": 1594612171.033565, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1594612171.033546}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.9431853921011351, "sum": 0.9431853921011351, "min": 0.9431853921011351}}, "EndTime": 1594612171.03363, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1594612171.033612}
#
# [07/13/2020 03:49:31 INFO 140591090407232] #quality_metric: host=algo-1, epoch=0, validation multiclass_cross_entropy_objective <loss>=0.426155206516
# [07/13/2020 03:49:31 INFO 140591090407232] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=multiclass_cross_entropy_objective, value=0.219341865449
# [07/13/2020 03:49:31 INFO 140591090407232] Epoch 0: Loss improved. Updating best model
# [07/13/2020 03:49:31 INFO 140591090407232] Saving model for epoch: 0
# [07/13/2020 03:49:31 INFO 140591090407232] Saved checkpoint to "/tmp/tmpQopHkA/mx-mod-0000.params"
# [07/13/2020 03:49:31 INFO 140591090407232] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 8, "sum": 8.0, "min": 8}, "Number of Batches Since Last Reset": {"count": 1, "max": 8, "sum": 8.0, "min": 8}, "Number of Records Since Last Reset": {"count": 1, "max": 14430, "sum": 14430.0, "min": 14430}, "Total Batches Seen": {"count": 1, "max": 15, "sum": 15.0, "min": 15}, "Total Records Seen": {"count": 1, "max": 28276, "sum": 28276.0, "min": 28276}, "Max Records Seen Between Resets": {"count": 1, "max": 14430, "sum": 14430.0, "min": 14430}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1594612171.042531, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1594612170.585038}
#
# [07/13/2020 03:49:31 INFO 140591090407232] #throughput_metric: host=algo-1, train throughput=31533.4585423 records/second
# [2020-07-13 03:49:31.399] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 356, "num_examples": 8, "num_bytes": 1904760}
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.32606415099083785, "sum": 0.32606415099083785, "min": 0.32606415099083785}}, "EndTime": 1594612171.399324, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1594612171.399229}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.32576376906575005, "sum": 0.32576376906575005, "min": 0.32576376906575005}}, "EndTime": 1594612171.399418, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1594612171.3994}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24598356404263866, "sum": 0.24598356404263866, "min": 0.24598356404263866}}, "EndTime": 1594612171.39948, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1594612171.399463}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.25929203168446663, "sum": 0.25929203168446663, "min": 0.25929203168446663}}, "EndTime": 1594612171.399548, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1594612171.399528}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.22947512578020615, "sum": 0.22947512578020615, "min": 0.22947512578020615}}, "EndTime": 1594612171.39961, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1594612171.399592}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2992759438999192, "sum": 0.2992759438999192, "min": 0.2992759438999192}}, "EndTime": 1594612171.39967, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1594612171.399654}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.27110212503202075, "sum": 0.27110212503202075, "min": 0.27110212503202075}}, "EndTime": 1594612171.39973, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1594612171.399713}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2974891690148554, "sum": 0.2974891690148554, "min": 0.2974891690148554}}, "EndTime": 1594612171.399793, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1594612171.399774}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2180851373337742, "sum": 0.2180851373337742, "min": 0.2180851373337742}}, "EndTime": 1594612171.399851, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1594612171.399835}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.29729383315169433, "sum": 0.29729383315169433, "min": 0.29729383315169433}}, "EndTime": 1594612171.399911, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1594612171.399895}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.5028505216491338, "sum": 0.5028505216491338, "min": 0.5028505216491338}}, "EndTime": 1594612171.399969, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1594612171.399953}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2650862763628146, "sum": 0.2650862763628146, "min": 0.2650862763628146}}, "EndTime": 1594612171.400028, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1594612171.400011}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.4594092098392022, "sum": 0.4594092098392022, "min": 0.4594092098392022}}, "EndTime": 1594612171.400088, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1594612171.40007}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.4051510365767302, "sum": 0.4051510365767302, "min": 0.4051510365767302}}, "EndTime": 1594612171.40015, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1594612171.400132}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.3024783808768665, "sum": 0.3024783808768665, "min": 0.3024783808768665}}, "EndTime": 1594612171.40021, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1594612171.400194}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6280666485215721, "sum": 0.6280666485215721, "min": 0.6280666485215721}}, "EndTime": 1594612171.400271, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1594612171.

#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.19818089415780984, "sum": 0.19818089415780984, "min": 0.19818089415780984}}, "EndTime": 1594612174.407078, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1594612174.407062}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.22727774390378244, "sum": 0.22727774390378244, "min": 0.22727774390378244}}, "EndTime": 1594612174.40714, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1594612174.407123}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2171205368945643, "sum": 0.2171205368945643, "min": 0.2171205368945643}}, "EndTime": 1594612174.40719, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1594612174.407175}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.19630527657704103, "sum": 0.19630527657704103, "min": 0.19630527657704103}}, "EndTime": 1594612174.407249, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1594612174.407233}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.31496464298461296, "sum": 0.31496464298461296, "min": 0.31496464298461296}}, "EndTime": 1594612174.40731, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1594612174.407292}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2879434016486446, "sum": 0.2879434016486446, "min": 0.2879434016486446}}, "EndTime": 1594612174.407371, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1594612174.407354}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6048057285057107, "sum": 0.6048057285057107, "min": 0.6048057285057107}}, "EndTime": 1594612174.407428, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1594612174.407411}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.3686873193386915, "sum": 0.3686873193386915, "min": 0.3686873193386915}}, "EndTime": 1594612174.407482, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1594612174.407466}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2270407292107304, "sum": 0.2270407292107304, "min": 0.2270407292107304}}, "EndTime": 1594612174.407614, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1594612174.407591}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.19775771018951813, "sum": 0.19775771018951813, "min": 0.19775771018951813}}, "EndTime": 1594612174.407709, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1594612174.407688}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.28106247094547554, "sum": 0.28106247094547554, "min": 0.28106247094547554}}, "EndTime": 1594612174.407803, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1594612174.407783}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.20106767115455795, "sum": 0.20106767115455795, "min": 0.20106767115455795}}, "EndTime": 1594612174.407923, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1594612174.407877}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.20342544237234736, "sum": 0.20342544237234736, "min": 0.20342544237234736}}, "EndTime": 1594612174.408008, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1594612174.407988}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.1986938407712916, "sum": 0.1986938407712916, "min": 0.1986938407712916}}, "EndTime": 1594612174.40809, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1594612174.40807}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2616364919594702, "sum": 0.2616364919594702, "min": 0.2616364919594702}}, "EndTime": 1594612174.408158, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1594612174.40814}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.1974318967454526, "sum": 0.1974318967454526, "min": 0.1974318967454526}}, "EndTime": 1594612174.408223, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1594612174.408205}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.43520286805335234, "sum": 0.43520286805335234, "min": 0.43520286805335234}}, "EndTime": 1594612174.408289, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1594612174.40827}
#
# [07/13/2020 03:49:34 INFO 140591090407232] #quality_metric: host=algo-1, epoch=7, validation multiclass_cross_entropy_objective <loss>=0.198011403694
# [07/13/2020 03:49:34 INFO 140591090407232] #early_stopping_criteria_metric: host=algo-1, epoch=7, criteria=multiclass_cross_entropy_objective, value=0.196305276577
# [07/13/2020 03:49:34 INFO 140591090407232] Saving model for epoch: 7
# [07/13/2020 03:49:34 INFO 140591090407232] Saved checkpoint to "/tmp/tmpoJuHnb/mx-mod-0000.params"
# [07/13/2020 03:49:34 INFO 140591090407232] Early stop condition met. Stopping training.
# [07/13/2020 03:49:34 INFO 140591090407232] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 8, "sum": 8.0, "min": 8}, "Number of Batches Since Last Reset": {"count": 1, "max": 8, "sum": 8.0, "min": 8}, "Number of Records Since Last Reset": {"count": 1, "max": 14430, "sum": 14430.0, "min": 14430}, "Total Batches Seen": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Total Records Seen": {"count": 1, "max": 129286, "sum": 129286.0, "min": 129286}, "Max Records Seen Between Resets": {"count": 1, "max": 14430, "sum": 14430.0, "min": 14430}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1594612174.416575, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1594612173.951001}
#
# [07/13/2020 03:49:34 INFO 140591090407232] #throughput_metric: host=algo-1, train throughput=30985.9521028 records/second
# [07/13/2020 03:49:34 WARNING 140591090407232] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [07/13/2020 03:49:34 WARNING 140591090407232] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2020-07-13 03:49:34.472] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 26, "duration": 36, "num_examples": 1, "num_bytes": 234036}
# [07/13/2020 03:49:34 INFO 140591090407232] #early_stopping_criteria_metric: host=algo-1, epoch=7, criteria=multiclass_cross_entropy_objective, value=0.196305276577
# [2020-07-13 03:49:34.519] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 28, "duration": 36, "num_examples": 1, "num_bytes": 234036}
# [07/13/2020 03:49:34 INFO 140591090407232] #validation_score (algo-1) : ('multiclass_cross_entropy_objective', 0.19614928063200612)
# [07/13/2020 03:49:34 INFO 140591090407232] #validation_score (algo-1) : ('multiclass_accuracy', 0.9390862944162437)
# [07/13/2020 03:49:34 INFO 140591090407232] #validation_score (algo-1) : ('multiclass_top_k_accuracy_3', 1.0)
# [07/13/2020 03:49:34 INFO 140591090407232] #validation_score (algo-1) : ('dcg', 0.9756724125775522)
# [07/13/2020 03:49:34 INFO 140591090407232] #validation_score (algo-1) : ('macro_recall', 0.9244284)
# [07/13/2020 03:49:34 INFO 140591090407232] #validation_score (algo-1) : ('macro_precision', 0.8905256)
# [07/13/2020 03:49:34 INFO 140591090407232] #validation_score (algo-1) : ('macro_f_1.000', 0.90638226)
# [07/13/2020 03:49:34 INFO 140591090407232] #quality_metric: host=algo-1, validation multiclass_cross_entropy_objective <loss>=0.196149280632
# [07/13/2020 03:49:34 INFO 140591090407232] #quality_metric: host=algo-1, validation multiclass_accuracy <score>=0.939086294416
# [07/13/2020 03:49:34 INFO 140591090407232] #quality_metric: host=algo-1, validation multiclass_top_k_accuracy_3 <score>=1.0
# [07/13/2020 03:49:34 INFO 140591090407232] #quality_metric: host=algo-1, validation dcg <score>=0.975672412578
# [07/13/2020 03:49:34 INFO 140591090407232] #quality_metric: host=algo-1, validation macro_recall <score>=0.924428403378
# [07/13/2020 03:49:34 INFO 140591090407232] #quality_metric: host=algo-1, validation macro_precision <score>=0.890525579453
# [07/13/2020 03:49:34 INFO 140591090407232] #quality_metric: host=algo-1, validation macro_f_1.000 <score>=0.906382262707
# [07/13/2020 03:49:34 INFO 140591090407232] Best model found for hyperparameters: {"lr_scheduler_step": 243, "wd": 0.007172148634657968, "optimizer": "adam", "lr_scheduler_factor": 0.9831300246895756, "l1": 9.376219031071712e-05, "learning_rate": 0.04578754213551083, "lr_scheduler_minimum_lr": 9.042943346173945e-05}
# [07/13/2020 03:49:34 INFO 140591090407232] Saved checkpoint to "/tmp/tmpm62wCC/mx-mod-0000.params"
# [07/13/2020 03:49:34 INFO 140591090407232] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 4375.277996063232, "sum": 4375.277996063232, "min": 4375.277996063232}, "finalize.time": {"count": 1, "max": 125.8080005645752, "sum": 125.8080005645752, "min": 125.8080005645752}, "initialize.time": {"count": 1, "max": 284.60192680358887, "sum": 284.60192680358887, "min": 284.60192680358887}, "check_early_stopping.time": {"count": 9, "max": 1.3530254364013672, "sum": 5.615472793579102, "min": 0.2338886260986328}, "setuptime": {"count": 1, "max": 24.07693862915039, "sum": 24.07693862915039, "min": 24.07693862915039}, "update.time": {"count": 8, "max": 560.028076171875, "sum": 3800.3292083740234, "min": 406.6967964172363}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1594612174.554903, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1594612170.260377}
#
#
# 2020-07-13 03:49:45 Completed - Training job completed
# Training seconds: 59
# Billable seconds: 59
# CPU times: user 730 ms, sys: 59.7 ms, total: 790 ms
# Wall time: 4min 43s

# %% [markdown]
# Now we can compare the amount of time billed and the accuracy compared to our baseline model.
